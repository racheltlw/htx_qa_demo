# %% [markdown]
# <a href="https://colab.research.google.com/github/racheltlw/htx_qa_demo/blob/main/QA_Multi_Demo_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Demo for Question and Answering System (Multi)
#
# This demo will walk you through how to train a Question and Answering pipeline using Haystack for Multiple Document QA

# %% [markdown]
# #### 1. Setup

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-3939d53f-78cd-4907-9a60-cf8880613ca1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3939d53f-78cd-4907-9a60-cf8880613ca1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving requirements.txt to requirements.txt
# User uploaded file "requirements.txt" with length 93 bytes

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting django_haystack==3.2.1
#   Downloading django-haystack-3.2.1.tar.gz (466 kB)
#      |████████████████████████████████| 466 kB 26.0 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ERROR: Could not find a version that satisfies the requirement numpy==1.23.1 (from versions: 1.3.0, 1.4.1, 1.5.0, 1.5.1, 1.6.0, 1.6.1, 1.6.2, 1.7.0, 1.7.1, 1.7.2, 1.8.0, 1.8.1, 1.8.2, 1.9.0, 1.9.1, 1.9.2, 1.9.3, 1.10.0.post2, 1.10.1, 1.10.2, 1.10.4, 1.11.0, 1.11.1, 1.11.2, 1.11.3, 1.12.0, 1.12.1, 1.13.0rc1, 1.13.0rc2, 1.13.0, 1.13.1, 1.13.3, 1.14.0rc1, 1.14.0, 1.14.1, 1.14.2, 1.14.3, 1.14.4, 1.14.5, 1.14.6, 1.15.0rc1, 1.15.0rc2, 1.15.0, 1.15.1, 1.15.2, 1.15.3, 1.15.4, 1.16.0rc1, 1.16.0rc2, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.16.4, 1.16.5, 1.16.6, 1.17.0rc1, 1.17.0rc2, 1.17.0, 1.17.1, 1.17.2, 1.17.3, 1.17.4, 1.17.5, 1.18.0rc1, 1.18.0, 1.18.1, 1.18.2, 1.18.3, 1.18.4, 1.18.5, 1.19.0rc1, 1.19.0rc2, 1.19.0, 1.19.1, 1.19.2, 1.19.3, 1.19.4, 1.19.5, 1.20.0rc1, 1.20.0rc2, 1.20.0, 1.20.1, 1.20.2, 1.20.3, 1.21.0rc1, 1.21.0rc2, 1.21.0, 1.21.1, 1.21.2, 1.21.3, 1.21.4, 1.21.5, 1.21.6)
# ERROR: No matching distribution found for numpy==1.23.1

# %%
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://download.pytorch.org/whl/cu113
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.12.1+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.13.1+cu113)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.7/dist-packages (0.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (4.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision) (2.23.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.21.6)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2022.6.15)

# %%
# !pip install git+https://github.com/deepset-ai/haystack.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/deepset-ai/haystack.git
#   Cloning https://github.com/deepset-ai/haystack.git to /tmp/pip-req-build-69xulz3h
#   Running command git clone -q https://github.com/deepset-ai/haystack.git /tmp/pip-req-build-69xulz3h
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting quantulum3
#   Downloading quantulum3-0.7.10-py3-none-any.whl (10.7 MB)
#      |████████████████████████████████| 10.7 MB 24.2 MB/s
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.7.2rc0) (4.3.3)
# Collecting rapidfuzz<3,>=2.0.15
#   Downloading rapidfuzz-2.6.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 59.6 MB/s
# Requirement already satisfied: pydantic in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.7.2rc0) (1.9.2)
# Collecting elastic-apm
#   Downloading elastic_apm-6.11.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (381 kB)
#      |████████████████████████████████| 381 kB 74.0 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.5 MB/s
# Collecting transformers==4.20.1
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 60.7 MB/s
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.7.2rc0) (2.6.3)
# Collecting huggingface-hub<0.8.0,>=0.5.0
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.7 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.7.2rc0) (4.12.0)
# Requirement already satisfied: torch<1.13,>1.9 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.7.2rc0) (1.12.1+cu113)
# Collecting tika
#   Downloading tika-1.24.tar.gz (28 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.7.2rc0) (0.3.5.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.7.2rc0) (4.64.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.7.2rc0) (1.0.2)
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 53.9 MB/s
# Collecting mmh3
#   Downloading mmh3-3.0.0-cp37-cp37m-manylinux2010_x86_64.whl (50 kB)
#      |████████████████████████████████| 50 kB 8.5 MB/s
# Collecting sentence-transformers>=2.2.0
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 6.3 MB/s
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 61.5 MB/s
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.7.2rc0) (1.7.3)
# Collecting elasticsearch<7.11,>=7.7
#   Downloading elasticsearch-7.10.1-py2.py3-none-any.whl (322 kB)
#      |████████████████████████████████| 322 kB 68.5 MB/s
# Collecting azure-ai-formrecognizer==3.2.0b2
#   Downloading azure_ai_formrecognizer-3.2.0b2-py2.py3-none-any.whl (219 kB)
#      |████████████████████████████████| 219 kB 24.7 MB/s
# Collecting posthog
#   Downloading posthog-2.1.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.7.2rc0) (8.14.0)
# Collecting mlflow
#   Downloading mlflow-1.28.0-py3-none-any.whl (17.0 MB)
#      |████████████████████████████████| 17.0 MB 222 kB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.7.2rc0) (2.23.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.7.2rc0) (3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.7.2rc0) (1.3.5)
# Collecting azure-common~=1.1
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting msrest>=0.6.21
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 5.5 MB/s
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from azure-ai-formrecognizer==3.2.0b2->farm-haystack==1.7.2rc0) (1.15.0)
# Collecting azure-core<2.0.0,>=1.13.0
#   Downloading azure_core-1.25.0-py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 73.9 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.20.1->farm-haystack==1.7.2rc0) (3.8.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 58.9 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.20.1->farm-haystack==1.7.2rc0) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.20.1->farm-haystack==1.7.2rc0) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.20.1->farm-haystack==1.7.2rc0) (2022.6.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.20.1->farm-haystack==1.7.2rc0) (6.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from azure-core<2.0.0,>=1.13.0->azure-ai-formrecognizer==3.2.0b2->farm-haystack==1.7.2rc0) (4.1.1)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from elasticsearch<7.11,>=7.7->farm-haystack==1.7.2rc0) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from elasticsearch<7.11,>=7.7->farm-haystack==1.7.2rc0) (2022.6.15)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack==1.7.2rc0) (1.3.1)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 803 kB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.20.1->farm-haystack==1.7.2rc0) (3.0.9)
# Collecting jarowinkler<2.0.0,>=1.2.0
#   Downloading jarowinkler-1.2.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (104 kB)
#      |████████████████████████████████| 104 kB 73.7 MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->farm-haystack==1.7.2rc0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->farm-haystack==1.7.2rc0) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack==1.7.2rc0) (3.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->farm-haystack==1.7.2rc0) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->farm-haystack==1.7.2rc0) (1.1.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=2.2.0->farm-haystack==1.7.2rc0) (0.13.1+cu113)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 62.7 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->farm-haystack==1.7.2rc0) (3.8.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->farm-haystack==1.7.2rc0) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->farm-haystack==1.7.2rc0) (5.9.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->farm-haystack==1.7.2rc0) (22.1.0)
# Collecting querystring-parser<2
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting gunicorn<21
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 10.7 MB/s
# Collecting databricks-cli<1,>=0.8.7
#   Downloading databricks-cli-0.17.2.tar.gz (81 kB)
#      |████████████████████████████████| 81 kB 10.4 MB/s
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack==1.7.2rc0) (0.4)
# Requirement already satisfied: cloudpickle<3 in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack==1.7.2rc0) (1.5.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack==1.7.2rc0) (0.4.2)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack==1.7.2rc0) (3.17.3)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack==1.7.2rc0) (7.1.2)
# Requirement already satisfied: pytz<2023 in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack==1.7.2rc0) (2022.2.1)
# Requirement already satisfied: Flask<3 in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack==1.7.2rc0) (1.1.4)
# Collecting docker<6,>=4.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 63.1 MB/s
# Collecting gitpython<4,>=2.1.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 71.1 MB/s
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from mlflow->farm-haystack==1.7.2rc0) (1.4.40)
# Collecting prometheus-flask-exporter<1
#   Downloading prometheus_flask_exporter-0.20.3-py3-none-any.whl (18 kB)
# Collecting alembic<2
#   Downloading alembic-1.8.1-py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 71.2 MB/s
# Collecting Mako
#   Downloading Mako-1.2.1-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 9.0 MB/s
# Collecting pyjwt>=1.7.0
#   Downloading PyJWT-2.4.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->farm-haystack==1.7.2rc0) (0.8.10)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.3.3-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.3 MB/s
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask<3->mlflow->farm-haystack==1.7.2rc0) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask<3->mlflow->farm-haystack==1.7.2rc0) (2.11.3)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask<3->mlflow->farm-haystack==1.7.2rc0) (1.0.1)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.3 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: setuptools>=3.0 in /usr/local/lib/python3.7/dist-packages (from gunicorn<21->mlflow->farm-haystack==1.7.2rc0) (57.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask<3->mlflow->farm-haystack==1.7.2rc0) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->farm-haystack==1.7.2rc0) (2.8.2)
# Collecting prometheus-client
#   Downloading prometheus_client-0.14.1-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 6.2 MB/s
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy<2,>=1.4.0->mlflow->farm-haystack==1.7.2rc0) (1.1.2)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff<2.0.0,>=1.10.0
#   Downloading backoff-1.11.1-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from python-docx->farm-haystack==1.7.2rc0) (4.9.1)
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (from quantulum3->farm-haystack==1.7.2rc0) (2.1.0)
# Collecting num2words
#   Downloading num2words-0.5.12-py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 73.6 MB/s
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=2.2.0->farm-haystack==1.7.2rc0) (7.1.2)
# Building wheels for collected packages: farm-haystack, sentence-transformers, langdetect, databricks-cli, python-docx, docopt, seqeval, tika
#   Building wheel for farm-haystack (PEP 517) ... done
#   Created wheel for farm-haystack: filename=farm_haystack-1.7.2rc0-py3-none-any.whl size=639432 sha256=0eac1da4af388eaac93fabf74639ee00b5f9c0630bd16c26f99cbab6cb558a9b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e9yjhked/wheels/a7/05/3b/9b33368d9af06a39f8e6af2e97fa2af876e893ade323cfc2c9
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=663a699b85a17bbc15dc302ee1f26144e838d87066a15cac2e8a1f71d5cfb401
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=b25680624083f92eb8654e55e317a37c5ad4c297beeb8502832242aeaf8e3cae
#   Stored in directory: /root/.cache/pip/wheels/c5/96/8a/f90c59ed25d75e50a8c10a1b1c2d4c402e4dacfa87f3aff36a
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.17.2-py3-none-any.whl size=143915 sha256=78e88c74064b26b83b3fec94b5fde44f5def903fea39f34eb79c924eac142e6b
#   Stored in directory: /root/.cache/pip/wheels/e4/94/af/ed16e5ddf301a3628d1d3e15ef95bbb79e076a3be48c11699b
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184507 sha256=1169b6ae05912b284b2e82c15ef7cd98a26eb68f09061d6f0e1ae48c7332839d
#   Stored in directory: /root/.cache/pip/wheels/f6/6f/b9/d798122a8b55b74ad30b5f52b01482169b445fbb84a11797a6
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=1537875e2ea3ea69d3108f80cf0e174418d294f0ee323d2b603c9703d80babd5
#   Stored in directory: /root/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=e638379bddfa5fc1f5d40703728a344e2cc95a3df0f4ad59febcec4773eaa31f
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-1.24-py3-none-any.whl size=32893 sha256=9713f5db77cf43759076574f169c009892f66d416f15155109184f716afe63d0
#   Stored in directory: /root/.cache/pip/wheels/ec/2b/38/58ff05467a742e32f67f5d0de048fa046e764e2fbb25ac93f3
# Successfully built farm-haystack sentence-transformers langdetect databricks-cli python-docx docopt seqeval tika
# Installing collected packages: smmap, websocket-client, tokenizers, pyjwt, prometheus-client, Mako, isodate, huggingface-hub, gitdb, docopt, azure-core, transformers, sentencepiece, querystring-parser, prometheus-flask-exporter, num2words, msrest, monotonic, jarowinkler, gunicorn, gitpython, docker, databricks-cli, backoff, azure-common, alembic, tika, seqeval, sentence-transformers, rapidfuzz, quantulum3, python-docx, posthog, mmh3, mlflow, langdetect, elasticsearch, elastic-apm, azure-ai-formrecognizer, farm-haystack
# Successfully installed Mako-1.2.1 alembic-1.8.1 azure-ai-formrecognizer-3.2.0b2 azure-common-1.1.28 azure-core-1.25.0 backoff-1.11.1 databricks-cli-0.17.2 docker-5.0.3 docopt-0.6.2 elastic-apm-6.11.0 elasticsearch-7.10.1 farm-haystack-1.7.2rc0 gitdb-4.0.9 gitpython-3.1.27 gunicorn-20.1.0 huggingface-hub-0.7.0 isodate-0.6.1 jarowinkler-1.2.1 langdetect-1.0.9 mlflow-1.28.0 mmh3-3.0.0 monotonic-1.6 msrest-0.7.1 num2words-0.5.12 posthog-2.1.0 prometheus-client-0.14.1 prometheus-flask-exporter-0.20.3 pyjwt-2.4.0 python-docx-0.8.11 quantulum3-0.7.10 querystring-parser-1.2.4 rapidfuzz-2.6.0 sentence-transformers-2.2.2 sentencepiece-0.1.97 seqeval-1.2.2 smmap-5.0.0 tika-1.24 tokenizers-0.12.1 transformers-4.20.1 websocket-client-1.3.3

# %% [markdown]
# Import packages

# %%
import pandas as pd
import pprint
from haystack.document_stores import InMemoryDocumentStore
from haystack.nodes import PreProcessor, DensePassageRetriever
from haystack.pipelines import ExtractiveQAPipeline
from haystack.nodes import FARMReader

# %% [markdown]
# #### 2. Create a document store
#
# Think of this as a database where your documents will be stored, to be used by the QA system

# %%
document_store = InMemoryDocumentStore() 
#you can also use a faiss document store which is optimised vector storage for DPR, for simplicity sake we will use InMemory

# %% [markdown]
# #### 3. Load and format your data
# The data a CSV file containing covid 19 related information. We will see how a haystack retriever can filter for the most relevant articles to a question, before using a QA model to extract the answer.

# %%
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-6787ae51-c682-4693-8872-b659c880d23e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6787ae51-c682-4693-8872-b659c880d23e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving multi_demo_covid.csv to multi_demo_covid.csv
# User uploaded file "multi_demo_covid.csv" with length 160284 bytes

# %%
#read data as a pandas dataframe
df = pd.read_csv('multi_demo_covid.csv') #load into the correct format for the haystack pipeline
#load reader and retriever

# %%
#reformat data so that haystack framework can use it
def get_docs(input_df):
    docs = []
    for i in range(len(input_df)): 
        doc = {
            'content': input_df['text'][i], 
            'meta': {'link': input_df['link'][i], 
                    'source': input_df['source'][i]}
        }
        docs.append(doc)
    return docs

# %%
#some articles are quite long so we need to split them into smaller chunks
preprocessor = PreProcessor(split_by = 'word', 
                            split_length = 300, #each chunk is 300 words long
                            split_overlap = 30, #each chunk overlaps with the previous chunk by 30 words
                            split_respect_sentence_boundary= True) #will split according to complete sentences
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
data = get_docs(df)
preprocessed_data = preprocessor.process(data)
# Out:
# Preprocessing:   0%|          | 0/213 [00:00<?, ?docs/s]

# %% [markdown]
# Write our data into the document store

# %%
document_store.write_documents(preprocessed_data)

# %% [markdown]
# #### 4. Load DPR and QA Model

# %% [markdown]
# Load the DPR

# %%
retriever = DensePassageRetriever(
    document_store=document_store,
    query_embedding_model="facebook/dpr-question_encoder-single-nq-base",
    passage_embedding_model="facebook/dpr-ctx_encoder-single-nq-base",
    max_seq_len_query=128, 
    max_seq_len_passage=512,
    batch_size=16,
    use_gpu=True, #if you do not have a gpu you can turn this off, it will just take longer
)

document_store.update_embeddings(retriever)
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/493 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/492 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'DPRQuestionEncoderTokenizer'.
# The class this function is called from is 'DPRContextEncoderTokenizerFast'.
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]
# Updating Embedding:   0%|          | 0/218 [00:00<?, ? docs/s]
# Create embeddings:   0%|          | 0/224 [00:00<?, ? Docs/s]
# Documents Processed: 10000 docs [00:09, 1093.51 docs/s]

# %% [markdown]
# Load the Reader (this is the QA model from Huggingface)

# %%
reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2", use_gpu=True)
# Out:
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/473M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/79.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]

# %% [markdown]
# Create a pipeline using both the retriever and reader

# %%
pipeline = ExtractiveQAPipeline(reader, retriever)

# %% [markdown]
# #### 5. Trying out our pipeline

# %% [markdown]
# Here is a simple function to allow us to display our results nicely

# %%
def print_preds_df(results):
    answers = results["answers"]
    pp = pprint.PrettyPrinter(indent=4)
    keys_to_keep = set(["answer", "context", "score", "probability"])

    # filter the results
    filtered_answers = []
    for ans in answers:
        filtered_answers.append({'answer': ans.answer, 'context': ans.context, 'score': ans.score, 
                               'link': ans.meta['link'], 'source': ans.meta['source']})

    df_res = pd.DataFrame({"answer":[], "context":[], "score":[], "link":[], "source":[]})

    for i in filtered_answers:
        df_res.loc[len(df_res)] = i

    df_res.sort_values(by=['score'], inplace = True, ascending=False)
    df_res = df_res.reset_index(drop = True)
    df_res['score'] = df_res['score'].round(2)
    return df_res

# %% [markdown]
# Run the pipeline on a question
# - The retriever filters out the top 20 most relevant articles
# - Then the QA finds the top 5 most probable answers from those articles

# %%
qn = 'Where did the coronavirus first appear? '
prediction = pipeline.run(query=qn, params={'Retriever': {'top_k': 20}, 'Reader': {'top_k':5}})
prediction_df = print_preds_df(prediction)
prediction_df #shows the top 5 answers by score
# Out:
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  3.97 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 31.30 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.23 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.16 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 17.37 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.06 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 27.15 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 33.84 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 17.69 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 36.66 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 38.69 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.08 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.94 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 21.41 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 25.25 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 32.10 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 38.45 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 40.18 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 50.43 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 43.90 Batches/s]
#         answer  \
# 0  Wuhan China
# 1        China
# 2      animals
# 3       humans
# 4   Wuhan City
#
#                                                                            context  \
# 0  t is causing the 2019 novel coronavirus outbreak, first identified in Wuhan ...
# 1  The novel coronavirus detected in China is genetically closely related to th...
# 2  Coronaviruses are a large family of viruses that are common in animals. Occa...
# 3  ily of viruses. There are some coronaviruses that commonly circulate in huma...
# 4  This virus was first detected in Wuhan City, Hubei Province, China. The firs...
#
#    score  \
# 0   0.97
# 1   0.85
# 2   0.77
# 3   0.73
# 4   0.70
#
#                                                                           link  \
# 0                         \nhttps://www.cdc.gov/coronavirus/2019-ncov/faq.html
# 1      https://www.ecdc.europa.eu/en/novel-coronavirus-china/questions-answers
# 2                   https://www.who.int/news-room/q-a-detail/q-a-coronaviruses
# 3  https://www.cdph.ca.gov/Programs/CID/DCDC/Pages/Immunization/nCoV2019.aspx#
# 4                         \nhttps://www.cdc.gov/coronavirus/2019-ncov/faq.html
#
#                                                       source
# 0            Center for Disease Control and Prevention (CDC)
# 1  European Centre for Disease Prevention and Control (ECDC)
# 2                            World Health Organization (WHO)
# 3                     California Department of Public Health
# 4            Center for Disease Control and Prevention (CDC)
